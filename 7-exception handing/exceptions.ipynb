# %% [markdown]
# ## Understanding exception

# %% [markdown]
# ### Exaption handing in python allous you to handle errors grocefully and take corrective action without stopping the exacetion of the program .This lesson will cover the basic of exceptions ,including how to use try except else and finally blocks.

# %% [markdown]
# ###

# %%
try:
    a=b
except NameError as ex :
    print(ex)
# Out:
# name 'b' is not defined

# %%
 a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined
