# %% [markdown]
# ## Class and Object

# %% [markdown]
# #### Object oriented programming (oop) is a programming parading that uses "object" to desing application and computer programes oop allows for modeling real world scenarios using class and object this lesson covers the basics of creating class and object including instance variables and method

# %%
## A class is a blue print for creating object ,Attributes method,

class car:
    pass

audi=car()
bmw=car()

print(type(bmw))
# Out:
# <class '__main__.car'>

# %%
print(bmw)
print(audi)

# %%
audi.window =4
print(audi.window)
# Out:
# 4

# %%
tata=car()
tata.doors=2
print(tata.doors)
# Out:
# 2

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## Instance variable and method

class dog:
    ## constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

## create a object 
dog1=dog("buddy",3)
print(dog1)
print(dog1,name)
print(dog1,age)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 12
#      10 dog1=dog("buddy",3)
#      11 print(dog1)
# ---> 12 print(dog1,name)
#      13 print(dog1,age)
#
# NameError: name 'name' is not defined
